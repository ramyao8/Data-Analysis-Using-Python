# %%
BREAST CANCER PREDICTION
import pandas as pd
mydf=pd.read_csv("/Coimbra_breast_cancer_dataset.csv")
mydf
# Out:
#      Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0     48  23.500000       70    2.707  0.467409   8.8071     9.702400
# 1     83  20.690495       92    3.115  0.706897   8.8438     5.429285
# 2     82  23.124670       91    4.498  1.009651  17.9393    22.432040
# 3     68  21.367521       77    3.226  0.612725   9.8827     7.169560
# 4     86  21.111111       92    3.549  0.805386   6.6994     4.819240
# ..   ...        ...      ...      ...       ...      ...          ...
# 111   45  26.850000       92    3.330  0.755688  54.6800    12.100000
# 112   62  26.840000      100    4.530  1.117400  12.4500    21.420000
# 113   65  32.050000       97    5.730  1.370998  61.4800    22.540000
# 114   72  25.590000       82    2.820  0.570392  24.9600    33.750000
# 115   86  27.180000      138   19.910  6.777364  90.2800    14.110000
#
#      Resistin    MCP.1  Classification
# 0     7.99585  417.114               1
# 1     4.06405  468.786               1
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
#linear regression
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
bmi=np.array(mydf['BMI']).reshape(-1,1)
insulin=np.array(mydf['Insulin'])
LR.fit(bmi,insulin)
LR.predict([[5.6]])
# Out:
# array([3.6067997])

# %%
print(classification.shape)
print(Resistin.shape)
# Out:
# (116, 1)
# (116,)

# %%
#decision tree classifier
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
BMI=float(input("enter bmi"))
Glucose=int(input("enter glucose"))
Insulin=float(input("enter insulin"))
HOMA=float(input("enter homa"))
Leptin=float(input("enter leptin"))
Adiponectin=float(input("enter adiponectin"))
Resistin=float(input("enter resistin"))
MCP1=float(input("enter mcp"))
features_cols=['BMI','Glucose','Insulin','HOMA','Leptin','Adiponectin','Resistin','MCP.1']
features=mydf[features_cols]
target=mydf.Classification
DT1=DecisionTreeClassifier()  #creating the model
model=DT1.fit(features,target)  #training the model
a=model.predict([[BMI,Glucose,Insulin,HOMA,Leptin,Adiponectin,Resistin,MCP1]])
if a==1:
  print("have cancer")
else:
  print("not having  cancer")
# Out:
# enter bmi19
# enter glucose345
# enter insulin120
# enter homa45
# enter leptin5
# enter adiponectin4
# enter resistin5
# enter mcp56
# have cancer
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import export_graphviz,plot_tree

# %%
from sklearn.tree import export_graphviz,plot_tree
plot_tree(DT1)
# Out:
# [Text(0.4659090909090909, 0.9545454545454546, 'x[1] <= 91.5\ngini = 0.495\nsamples = 116\nvalue = [52, 64]'),
#  Text(0.22727272727272727, 0.8636363636363636, 'x[6] <= 13.248\ngini = 0.42\nsamples = 50\nvalue = [35, 15]'),
#  Text(0.13636363636363635, 0.7727272727272727, 'x[6] <= 3.281\ngini = 0.185\nsamples = 29\nvalue = [26, 3]'),
#  Text(0.09090909090909091, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18181818181818182, 0.6818181818181818, 'x[2] <= 30.067\ngini = 0.133\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.13636363636363635, 0.5909090909090909, 'x[5] <= 3.986\ngini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(0.09090909090909091, 0.5, 'x[2] <= 3.793\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.045454545454545456, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13636363636363635, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
# ...

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
BMI=float(input("enter bmi"))
Glucose=int(input("enter glucose"))
Insulin=float(input("enter insulin"))
HOMA=float(input("enter homa i.e.used to quantify insulin resistance and beta-cell function"))
Leptin=float(input("enter leptin"))
Adiponectin=float(input("enter adiponectin"))
Resistin=float(input("enter resistin"))
MCP1=float(input("enter mcp"))
features_cols=['BMI','Glucose','Insulin','HOMA','Leptin','Adiponectin','Resistin','MCP.1']
features=mydf[features_cols]
target=mydf.Classification
RF1=RandomForestClassifier()  #creating model
model=RF1.fit(features,target)  #training model
n_estimators=10
a=model.predict([[BMI,Glucose,Insulin,HOMA,Leptin,Adiponectin,Resistin,MCP1]])
if a==1:
  print("have cancer")
else:
  print("not having  cancer")
# Out:
# enter bmi23
# enter glucose342
# enter insulin123
# enter homa i.e.used to quantify insulin resistance and beta-cell function1
# enter leptin234
# enter adiponectin45
# enter resistin12
# enter mcp8
# not having  cancer
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import os
output_dir ="tree_visualizations_on_breast_cancer"
os.makedirs(output_dir,exist_ok=True)

# %%
for i, tree in enumerate(model.estimators_):
  tree_dot_file=os.path.join(output_dir,f"tree_{i}.dot")
  tree_png_file=os.path.join(output_dir,f"tree_{i}.png")

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file=tree_dot_file, feature_names=['BMI','Glucose','Insulin','HOMA','Leptin','Adiponectin','Resistin','MCP.1'],
                    class_names=[str(cls) for cls in model.classes_], filled=True, rounded=True)

# %%
command=f"dot -Tpng {tree_dot_file} -o {tree_png_file}"
os.system(command)
print(f"Tree {i} visualization saved to {tree_png_file}")
# Out:
# Tree 99 visualization saved to tree_visualizations_on_breast_cancer/tree_99.png

# %%
#EMPLOYE RECRUITMENT
import pandas as pd
df=pd.read_csv("/content/employement_project2.csv")
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  Unnamed: 14  \
# ...

# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
#Decision tree algorithm
import numpy as np
from sklearn.tree import DecisionTreeClassifier
ssc_p=float(input("Enter SSC percentage:"))
hsc_p=float(input("Enter HSC percentage:"))
degree_p=float(input("Enter degree percentage:"))
etest_p	=float(input("Enter entrance percentage:"))
mba_p=float(input("Enter MBA percentage:"))
feature_col=['ssc_p','hsc_p','degree_p','etest_p','mba_p']
feature=df[feature_col]#features
Target=df.status #Target variable
DT=DecisionTreeClassifier()#creating the model
model=DT.fit(feature,Target)#fitting the model
print(model)
a=model.predict([[ssc_p,hsc_p,degree_p,etest_p,mba_p]])
if a == "Placed":
  print("Yay! you are PLACED..")
else:
  print("Sorry you are NOT PLACED Better luck next time!")
# Out:
# Enter SSC percentage:68
# Enter HSC percentage:55
# Enter degree percentage:91
# Enter entrance percentage:58.5
# Enter MBA percentage:55
# DecisionTreeClassifier()
# Yay! you are PLACED..
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import export_graphviz,plot_tree
plot_tree(DT)
# Out:
# [Text(0.31896551724137934, 0.95, 'x[0] <= 56.44\ngini = 0.429\nsamples = 215\nvalue = [67, 148]'),
#  Text(0.13793103448275862, 0.85, 'x[1] <= 58.5\ngini = 0.188\nsamples = 38\nvalue = [34, 4]'),
#  Text(0.10344827586206896, 0.75, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.1724137931034483, 0.75, 'x[4] <= 58.37\ngini = 0.36\nsamples = 17\nvalue = [13, 4]'),
#  Text(0.06896551724137931, 0.65, 'x[0] <= 52.3\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.034482758620689655, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10344827586206896, 0.55, 'x[0] <= 55.98\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.06896551724137931, 0.45, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.13793103448275862, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.27586206896551724, 0.65, 'x[1] <= 59.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.2413793103448276, 0.55, 'x[3] <= 82.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
# ...

# %%
from sklearn.tree import export_graphviz,plot_tree
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.tree import export_graphviz,plot_tree
from sklearn.ensemble import RandomForestClassifier
ssc_p=float(input("Enter SSC percentage:"))
hsc_p=float(input("Enter HSC percentage:"))
degree_p=float(input("Enter degree percentage:"))
etest_p	=float(input("Enter entrance percentage:"))
mba_p=float(input("Enter MBA percentage:"))
feature_col=['ssc_p','hsc_p','degree_p','etest_p','mba_p']
feature=df[feature_col]#features
Target=df.status #Target variable
RF=RandomForestClassifier()#creating the model
model=RF.fit(feature,Target)#fitting the model
n_estimators=10
print(model)
res=model.predict([[ssc_p,hsc_p,degree_p,etest_p,mba_p]])
if res=="Placed":
  print("you are placed")
else:
  print("you are not placed")
# Out:
# Enter SSC percentage:66
# Enter HSC percentage:91
# Enter degree percentage:55
# Enter entrance percentage:58.5
# Enter MBA percentage:55
# RandomForestClassifier()
# you are placed
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
#creating a folder
#saving all decisions
import os
output_dir=" Placements Tree Visualization"
os.makedirs(output_dir,exist_ok=True)

# %%
#writing path
for i,tree in enumerate(model.estimators_):
  tree_dot_file=os.path.join(output_dir,f"tree_{i}.dot")
  tree_png_file=os.path.join(output_dir,f"tree_{i}.png")

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file=tree_dot_file, feature_names=['ssc_p','hsc_p','degree_p','etest_p','mba_p'],
                    class_names=[str(cls) for cls in model.classes_], filled=True, rounded=True)

# %%
command=f"dot -Tpng {tree_dot_file} -o {tree_png_file}"
os.system(command)
print(f"Tree {i} visualization saved to {tree_png_file}")
# Out:
# Tree 99 visualization saved to  Placements Tree Visualization/tree_99.png

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/content/data.csv", encoding='latin1')
df
# Out:
# <ipython-input-25-a433be7183f8>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/data.csv", encoding='latin1')
#        stn_code       sampling_date           state   location  \
# 0         150.0  February - M021990  Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990  Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990  Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990  Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990  Andhra Pradesh  Hyderabad
# ...         ...                 ...             ...        ...
# 146131    457.0           11/4/2013       Karnataka  Bangalore
# 146132    457.0           11/6/2013       Karnataka  Bangalore
# 146133    457.0          11/11/2013       Karnataka  Bangalore
# 146134    457.0            14-11-13       Karnataka  Bangalore
# 146135    457.0            21-11-13       Karnataka  Bangalore
#
# ...

# %%
data=df[df["state"]=="Gujarat"]
sns.catplot(data=data,x="location",y="so2",kind="box")

# %%
#project-3---> EMPLOYEMENT ATTRITION
import pandas as pd
mydf3=pd.read_csv("/content/WA_Fn-UseC_-HR-Employee-Attrition.csv")
mydf3
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#Decision tree
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
DistanceFromHome=int(input("enter DistanceFromHome"))
DailyRate=int(input("enter DailyRate"))
WorkLifeBalance=int(input("enter WorkLifeBalance"))
JobSatisfaction=int(input("enter JobSatisfaction	"))
features_col=['DistanceFromHome','DailyRate','WorkLifeBalance','JobSatisfaction']
features=mydf3[features_col]
target=mydf3.Attrition
DT2=DecisionTreeClassifier()
model=DT2.fit(features,target)
a=model.predict([[DistanceFromHome,DailyRate,WorkLifeBalance,JobSatisfaction]])
if a=="Yes":
  print("leave the company")
else:
  print("not leave the company")
# Out:
# enter DistanceFromHome6
# enter DailyRate613
# enter WorkLifeBalance3
# enter JobSatisfaction	1
# not leave the company
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import export_graphviz,plot_tree
plot_tree(DT2)
# Out:
# [Text(0.31258839399491534, 0.9871794871794872, 'x[2] <= 1.5\ngini = 0.27\nsamples = 1470\nvalue = [1233, 237]'),
#  Text(0.08533447684391081, 0.9615384615384616, 'x[1] <= 1146.0\ngini = 0.43\nsamples = 80\nvalue = [55, 25]'),
#  Text(0.07332761578044597, 0.9358974358974359, 'x[1] <= 1091.0\ngini = 0.479\nsamples = 58\nvalue = [35, 23]'),
#  Text(0.06646655231560893, 0.9102564102564102, 'x[1] <= 996.5\ngini = 0.46\nsamples = 53\nvalue = [34, 19]'),
#  Text(0.0630360205831904, 0.8846153846153846, 'x[0] <= 25.5\ngini = 0.475\nsamples = 49\nvalue = [30, 19]'),
#  Text(0.05960548885077187, 0.8589743589743589, 'x[0] <= 22.0\ngini = 0.485\nsamples = 46\nvalue = [27, 19]'),
#  Text(0.05274442538593482, 0.8333333333333334, 'x[0] <= 17.5\ngini = 0.464\nsamples = 41\nvalue = [26, 15]'),
#  Text(0.049313893653516294, 0.8076923076923077, 'x[0] <= 9.5\ngini = 0.482\nsamples = 37\nvalue = [22, 15]'),
# ...

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
DistanceFromHome=int(input("enter DistanceFromHome"))
DailyRate=int(input("enter DailyRate"))
WorkLifeBalance=int(input("enter WorkLifeBalance"))
JobSatisfaction=int(input("enter JobSatisfaction	"))
features_col=['DistanceFromHome','DailyRate','WorkLifeBalance','JobSatisfaction']
features=mydf3[features_col]
target=mydf3.Attrition
RF2=RandomForestClassifier()
model=RF2.fit(features,target)
n_estimators=10
a=model.predict([[DistanceFromHome,DailyRate,WorkLifeBalance,JobSatisfaction]])
if a=="Yes":
  print("leave the company")
else:
  print("not leave the company")
# Out:
# enter DistanceFromHome1
# enter DailyRate740
# enter WorkLifeBalance3
# enter JobSatisfaction	1
# leave the company
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import os
output_dir ="tree_visualizations_on_HR_employee_attrition"
os.makedirs(output_dir,exist_ok=True)

# %%
for i, tree in enumerate(model.estimators_):
  tree_dot_file=os.path.join(output_dir,f"tree_{i}.dot")
  tree_png_file=os.path.join(output_dir,f"tree_{i}.png")

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file=tree_dot_file, feature_names=['DistanceFromHome','DailyRate','WorkLifeBalance','JobSatisfaction'],
                    class_names=[str(cls) for cls in model.classes_], filled=True, rounded=True)

# %%
command=f"dot -Tpng {tree_dot_file} -o {tree_png_file}"
os.system(command)
print(f"Tree {i} visualization saved to {tree_png_file}")
# Out:
# Tree 99 visualization saved to tree_visualizations_on_HR_employee_attrition/tree_99.png

# %%
#linear regression
import numpy as np
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
DailyRate=np.array(mydf3['DailyRate']).reshape(-1,1)
DistanceFromHome=np.array(mydf3['DistanceFromHome'])
LR.fit(DailyRate,DistanceFromHome)
LR.predict([[8.6]])
# Out:
# array([9.27203257])
